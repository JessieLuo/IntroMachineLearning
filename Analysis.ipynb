# %%
import pandas as pd

data_train = pd.read_csv("train.csv", index_col=None)
data_test = pd.read_csv("test.csv", index_col=None)
print(data_train.head())
print(data_test.head())

# print(data_train.describe())
# print(data_test.describe())
